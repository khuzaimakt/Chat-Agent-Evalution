# %%
# !python -m pip install -U garak

# %%
# %pip install -U langgraph langchain_community langchain_openai tavily-python

# %%
import Chat_Agent
from Chat_Agent import probing_function

# %%
# !python3 -m garak --list_probes

# %%
# !python -m garak --model_type function --model_name Chat_Agent#probing_function --probes atkgen.Tox
# Out:
# garak LLM security probe v0.9.0.11.post1 ( https://github.com/leondz/garak ) at 2024-03-22T18:07:25.045274
# 📜 reporting to runs/garak.7362e83a-4eaa-441d-b3ac-351b12acc6f2.report.jsonl
# 🦜 loading generator: function: mymodule#myfunction
# 🕵️  queue of probes: atkgen.Tox
# 2024-03-22 18:07:35.921594: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-22 18:07:35.921716: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-22 18:07:36.082133: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
